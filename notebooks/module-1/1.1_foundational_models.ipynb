# %%
from dotenv import load_dotenv

load_dotenv()
# Out:
# True

# %% [markdown]
# ## Initialising and invoking a model

# %%
from langchain.chat_models import init_chat_model

model = init_chat_model(model="google_genai:gemini-2.5-flash-lite")

# %%
response = model.invoke("What's the capital of the Moon?")

response
# Out:
# AIMessage(content='That\'s a fun question! The Moon doesn\'t have a capital city like countries on Earth do. It\'s a celestial body, not a political entity.\n\nHowever, if we were to imagine a "capital" based on significant human activity and historical importance, **Tranquility Base** would be the most fitting choice. This is the landing site of Apollo 11, where Neil Armstrong and Buzz Aldrin first walked on the Moon. It\'s a landmark of immense historical and symbolic significance.', additional_kwargs={}, response_metadata={'finish_reason': 'STOP', 'model_name': 'gemini-2.5-flash-lite', 'safety_ratings': [], 'model_provider': 'google_genai'}, id='lc_run--019c1e2d-9357-7541-b610-1a48c3c3f2f3-0', usage_metadata={'input_tokens': 10, 'output_tokens': 104, 'total_tokens': 114, 'input_token_details': {'cache_read': 0}})

# %%
print(response.content)
# Out:
# That's a fun question! The Moon doesn't have a capital city like countries on Earth do. It's a celestial body, not a political entity.
#
# However, if we were to imagine a "capital" based on significant human activity and historical importance, **Tranquility Base** would be the most fitting choice. This is the landing site of Apollo 11, where Neil Armstrong and Buzz Aldrin first walked on the Moon. It's a landmark of immense historical and symbolic significance.

# %%
from pprint import pprint

pprint(response.response_metadata)
# Out:
# {'finish_reason': 'STOP',
#  'model_name': 'gemini-2.5-flash-lite',
#  'model_provider': 'google_genai',
#  'safety_ratings': []}

# %% [markdown]
# ## Customising your Model

# %%
model = init_chat_model(
    model="google_genai:gemini-2.5-flash-lite",
    # Kwargs passed to the model:
    temperature=1.0
)

response = model.invoke("What's the capital of the Moon?")
print(response.content)
# Out:
# That's a fun question! The Moon doesn't have a capital city because it's not a country or a populated place like Earth. It's a natural celestial body with no governments or human settlements.
#
# However, if we were to get creative and imagine a "capital" based on its most significant features, some might jokingly suggest:
#
# *   **The Sea of Tranquility:** This is where the Apollo 11 landing happened, making it historically significant for humanity's first steps on the Moon.
# *   **Any prominent crater:** Given the Moon's cratered surface, a large and well-known crater could be considered a landmark.
#
# But in reality, the Moon has no capital. 😊

# %% [markdown]
# ## Model Providers

# %% [markdown]
# https://docs.langchain.com/oss/python/integrations/chat

# %%
model = init_chat_model(model="claude-sonnet-4-5")

response = model.invoke("What's the capital of the Moon?")
print(response.content)
# Out:
# ---------------------------------------------------------------------------
# BadRequestError                           Traceback (most recent call last)
# Cell In[22], line 3
#       1 model = init_chat_model(model="claude-sonnet-4-5")
# ----> 3 response = model.invoke("What's the capital of the Moon?")
#       4 print(response.content)
#
# File ~/lca-lc-foundations/.venv/lib/python3.13/site-packages/langchain_core/language_models/chat_models.py:398, in BaseChatModel.invoke(self, input, config, stop, **kwargs)
#     384 @override
#     385 def invoke(
#     386     self,
#    (...)    391     **kwargs: Any,
#     392 ) -> AIMessage:
#     393     config = ensure_config(config)
#     394     return cast(
#     395         "AIMessage",
#     396         cast(
#     397             "ChatGeneration",
# --> 398             self.generate_prompt(
#     399                 [self._convert_input(input)],
#     400                 stop=stop,
#     401                 callbacks=config.get("callbacks"),
#     402                 tags=config.get("tags"),
#     403                 metadata=config.get("metadata"),
#     404                 run_name=config.get("run_name"),
#     405                 run_id=config.pop("run_id", None),
#     406                 **kwargs,
#     407             ).generations[0][0],
#     408         ).message,
#     409     )
#
# File ~/lca-lc-foundations/.venv/lib/python3.13/site-packages/langchain_core/language_models/chat_models.py:1117, in BaseChatModel.generate_prompt(self, prompts, stop, callbacks, **kwargs)
#    1108 @override
#    1109 def generate_prompt(
#    1110     self,
#    (...)   1114     **kwargs: Any,
#    1115 ) -> LLMResult:
#    1116     prompt_messages = [p.to_messages() for p in prompts]
# -> 1117     return self.generate(prompt_messages, stop=stop, callbacks=callbacks, **kwargs)
#
# File ~/lca-lc-foundations/.venv/lib/python3.13/site-packages/langchain_core/language_models/chat_models.py:927, in BaseChatModel.generate(self, messages, stop, callbacks, tags, metadata, run_name, run_id, **kwargs)
#     924 for i, m in enumerate(input_messages):
#     925     try:
#     926         results.append(
# --> 927             self._generate_with_cache(
#     928                 m,
#     929                 stop=stop,
#     930                 run_manager=run_managers[i] if run_managers else None,
#     931                 **kwargs,
#     932             )
#     933         )
#     934     except BaseException as e:
#     935         if run_managers:
#
# File ~/lca-lc-foundations/.venv/lib/python3.13/site-packages/langchain_core/language_models/chat_models.py:1221, in BaseChatModel._generate_with_cache(self, messages, stop, run_manager, **kwargs)
#    1219     result = generate_from_stream(iter(chunks))
#    1220 elif inspect.signature(self._generate).parameters.get("run_manager"):
# -> 1221     result = self._generate(
#    1222         messages, stop=stop, run_manager=run_manager, **kwargs
#    1223     )
#    1224 else:
#    1225     result = self._generate(messages, stop=stop, **kwargs)
#
# File ~/lca-lc-foundations/.venv/lib/python3.13/site-packages/langchain_anthropic/chat_models.py:1917, in ChatAnthropic._generate(self, messages, stop, run_manager, **kwargs)
#    1915     data = self._create(payload)
#    1916 except anthropic.BadRequestError as e:
# -> 1917     _handle_anthropic_bad_request(e)
#    1918 return self._format_output(data, **kwargs)
#
# File ~/lca-lc-foundations/.venv/lib/python3.13/site-packages/langchain_anthropic/chat_models.py:1915, in ChatAnthropic._generate(self, messages, stop, run_manager, **kwargs)
#    1913 payload = self._get_request_payload(messages, stop=stop, **kwargs)
#    1914 try:
# -> 1915     data = self._create(payload)
#    1916 except anthropic.BadRequestError as e:
#    1917     _handle_anthropic_bad_request(e)
#
# File ~/lca-lc-foundations/.venv/lib/python3.13/site-packages/langchain_anthropic/chat_models.py:1777, in ChatAnthropic._create(self, payload)
#    1775 if "betas" in payload:
#    1776     return self._client.beta.messages.create(**payload)
# -> 1777 return self._client.messages.create(**payload)
#
# File ~/lca-lc-foundations/.venv/lib/python3.13/site-packages/anthropic/_utils/_utils.py:282, in required_args.<locals>.inner.<locals>.wrapper(*args, **kwargs)
#     280             msg = f"Missing required argument: {quote(missing[0])}"
#     281     raise TypeError(msg)
# --> 282 return func(*args, **kwargs)
#
# File ~/lca-lc-foundations/.venv/lib/python3.13/site-packages/anthropic/resources/messages/messages.py:930, in Messages.create(self, max_tokens, messages, model, metadata, service_tier, stop_sequences, stream, system, temperature, thinking, tool_choice, tools, top_k, top_p, extra_headers, extra_query, extra_body, timeout)
#     923 if model in DEPRECATED_MODELS:
#     924     warnings.warn(
#     925         f"The model '{model}' is deprecated and will reach end-of-life on {DEPRECATED_MODELS[model]}.\nPlease migrate to a newer model. Visit https://docs.anthropic.com/en/docs/resources/model-deprecations for more information.",
#     926         DeprecationWarning,
#     927         stacklevel=3,
#     928     )
# --> 930 return self._post(
#     931     "/v1/messages",
#     932     body=maybe_transform(
#     933         {
#     934             "max_tokens": max_tokens,
#     935             "messages": messages,
#     936             "model": model,
#     937             "metadata": metadata,
#     938             "service_tier": service_tier,
#     939             "stop_sequences": stop_sequences,
#     940             "stream": stream,
#     941             "system": system,
#     942             "temperature": temperature,
#     943             "thinking": thinking,
#     944             "tool_choice": tool_choice,
#     945             "tools": tools,
#     946             "top_k": top_k,
#     947             "top_p": top_p,
#     948         },
#     949         message_create_params.MessageCreateParamsStreaming
#     950         if stream
#     951         else message_create_params.MessageCreateParamsNonStreaming,
#     952     ),
#     953     options=make_request_options(
#     954         extra_headers=extra_headers, extra_query=extra_query, extra_body=extra_body, timeout=timeout
#     955     ),
#     956     cast_to=Message,
#     957     stream=stream or False,
#     958     stream_cls=Stream[RawMessageStreamEvent],
#     959 )
#
# File ~/lca-lc-foundations/.venv/lib/python3.13/site-packages/anthropic/_base_client.py:1326, in SyncAPIClient.post(self, path, cast_to, body, options, files, stream, stream_cls)
#    1312 def post(
#    1313     self,
#    1314     path: str,
#    (...)   1321     stream_cls: type[_StreamT] | None = None,
#    1322 ) -> ResponseT | _StreamT:
#    1323     opts = FinalRequestOptions.construct(
#    1324         method="post", url=path, json_data=body, files=to_httpx_files(files), **options
#    1325     )
# -> 1326     return cast(ResponseT, self.request(cast_to, opts, stream=stream, stream_cls=stream_cls))
#
# File ~/lca-lc-foundations/.venv/lib/python3.13/site-packages/anthropic/_base_client.py:1114, in SyncAPIClient.request(self, cast_to, options, stream, stream_cls)
#    1111             err.response.read()
#    1113         log.debug("Re-raising status error")
# -> 1114         raise self._make_status_error_from_response(err.response) from None
#    1116     break
#    1118 assert response is not None, "could not resolve response (should never happen)"
#
# BadRequestError: Error code: 400 - {'type': 'error', 'error': {'type': 'invalid_request_error', 'message': 'Your credit balance is too low to access the Anthropic API. Please go to Plans & Billing to upgrade or purchase credits.'}, 'request_id': 'req_011CXjBxQFha3JnpZzYThbaz'}

# %%
from langchain_google_genai import ChatGoogleGenerativeAI

model = ChatGoogleGenerativeAI(model="gemini-2.5-flash-lite")

response = model.invoke("What's the capital of the Moon?")
print(response.content)
# Out:
# The Moon doesn't have a capital city, or any cities at all for that matter. It's a natural celestial body without any form of organized government or settlements.

# %% [markdown]
# ## Initialising and invoking an agent

# %%
from langchain.agents import create_agent

agent = create_agent(model=model)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 3
#       1 from langchain.agents import create_agent
# ----> 3 agent = create_agent(model=model)
#
# NameError: name 'model' is not defined

# %%
agent = create_agent(model="google_genai:gemini-2.5-flash-lite")

# %%
agent = create_agent("gpt-5-nano")

# %%
from langchain.messages import HumanMessage

response = agent.invoke(
    {"messages": [HumanMessage(content="What's the capital of the Moon?")]}
)

# %%
from pprint import pprint

pprint(response)
# Out:
# {'messages': [HumanMessage(content="What's the capital of the Moon?", additional_kwargs={}, response_metadata={}, id='6bad608d-c024-402f-aff3-c659e1deeffe'),
#               AIMessage(content='That\'s a fun question! The Moon doesn\'t have a capital city like Earth does. It\'s a celestial body without any permanent human settlements or governments.\n\nHowever, if you\'re thinking in terms of *exploration* and *historical significance*, you could make a case for:\n\n*   **Tranquility Base:** This is where Neil Armstrong and Buzz Aldrin first landed during the Apollo 11 mission in 1969. It\'s a incredibly important historical site and arguably the most famous "location" on the Moon.', additional_kwargs={}, response_metadata={'finish_reason': 'STOP', 'model_name': 'gemini-2.5-flash-lite', 'safety_ratings': [], 'model_provider': 'google_genai'}, id='lc_run--019c1e3b-3d3d-7870-b0d5-8d7cef9c8a40-0', usage_metadata={'input_tokens': 10, 'output_tokens': 114, 'total_tokens': 124, 'input_token_details': {'cache_read': 0}})]}

# %%
print(response['messages'][-1].content)
# Out:
# That's a fun question! The Moon doesn't have a capital city like Earth does. It's a celestial body without any permanent human settlements or governments.
#
# However, if you're thinking in terms of *exploration* and *historical significance*, you could make a case for:
#
# *   **Tranquility Base:** This is where Neil Armstrong and Buzz Aldrin first landed during the Apollo 11 mission in 1969. It's a incredibly important historical site and arguably the most famous "location" on the Moon.

# %%
from langchain.messages import AIMessage

response = agent.invoke(
    {"messages": [HumanMessage(content="What's the capital of the Moon?"),
    AIMessage(content="The capital of the Moon is Luna City."),
    HumanMessage(content="Interesting, tell me more about Luna City")]}
)

pprint(response)
# Out:
# {'messages': [HumanMessage(content="What's the capital of the Moon?", additional_kwargs={}, response_metadata={}, id='12d534c9-1580-40b3-a798-d6d7a8a5d524'),
#               AIMessage(content='The capital of the Moon is Luna City.', additional_kwargs={}, response_metadata={}, id='990bafd7-bc10-4147-bdfa-2f219bd4c286'),
#               HumanMessage(content='Interesting, tell me more about Luna City', additional_kwargs={}, response_metadata={}, id='7ed67141-c414-4cb9-ab13-3b6b57e159c0'),
#               AIMessage(content='While I\'d love to tell you more about Luna City, it\'s important to understand that **Luna City is not a real place.** It\'s a fictional city that exists in science fiction stories, movies, and games.\n\nIn these fictional narratives, Luna City is often depicted as:\n\n*   **A thriving human settlement:** Established on the Moon to exploit its resources, serve as a scientific research hub, or as a base for further space exploration.\n*   **A futuristic metropolis:** Featuring advanced technology, domed habitats to protect inhabitants from the vacuum and radiation, and potentially unique architecture adapted to the lunar environment (lower gravity, no atmosphere).\n*   **A center of governance or commerce:** Sometimes it\'s portrayed as the administrative or economic capital of lunar colonies, or even a significant entity in a future interstellar society.\n*   **A setting for adventure and conflict:** As with many fictional locations, Luna City can be the stage for exciting plots, political intrigue, or even battles.\n\n**Famous fictional portrayals of Luna City (or similar lunar cities) can be found in:**\n\n*   **Movies:** Think of science fiction films set on the Moon.\n*   **Books:** Many novels have explored the concept of lunar colonies.\n*   **Video Games:** Several games have featured playable or explorable lunar cities.\n\n**So, to reiterate, while "Luna City" is a captivating idea and a staple of science fiction, it\'s a product of imagination, not reality.** There are no established cities or capitals on the Moon today.\n\nIf you\'re interested in the **real** exploration and future possibilities of the Moon, I can tell you about:\n\n*   **Current lunar missions:** Like NASA\'s Artemis program, which aims to return humans to the Moon.\n*   **The challenges of lunar settlement:** Such as life support, radiation shielding, and resource utilization.\n*   **The scientific interest in the Moon:** What we\'re learning about its geology and history.\n\nLet me know if you\'d like to explore any of those!', additional_kwargs={}, response_metadata={'finish_reason': 'STOP', 'model_name': 'gemini-2.5-flash-lite', 'safety_ratings': [], 'model_provider': 'google_genai'}, id='lc_run--019c1e3c-2e41-7c93-a0af-214d83889433-0', usage_metadata={'input_tokens': 29, 'output_tokens': 429, 'total_tokens': 458, 'input_token_details': {'cache_read': 0}})]}

# %% [markdown]
# ## Streaming Output

# %%
for token, metadata in agent.stream(
    {"messages": [HumanMessage(content="Tell me all about Luna City, the capital of the Moon")]},
    stream_mode="messages"
):

    # token is a message chunk with token content
    # metadata contains which node produced the token
    
    if token.content:  # Check if there's actual content
        print(token.content, end="", flush=True)  # Print token
# Out:
# Luna City, the capital of the Moon, is a testament to humanity's audacious spirit and our ability to adapt to the most extreme environments. While it's currently a concept, a dream etched into the blueprints of future lunar exploration, its existence is envisioned as a vibrant, functional, and aesthetically inspiring hub on Earth's closest celestial neighbor.
#
# Here's a comprehensive look at what Luna City is, and what it's envisioned to be:
#
# **The Genesis of Luna City:**
#
# The idea of a lunar capital isn't born out of pure fantasy, but rather from the practical needs and aspirations of a growing human presence on the Moon. As lunar bases expand from temporary research outposts to more permanent settlements, the need for a central administrative, economic, and social hub becomes apparent. Luna City represents this evolution, a place where various lunar endeavors converge and a sense of lunar identity can truly flourish.
#
# **Location, Location, Location:**
#
# The precise location of Luna City is still a subject of ongoing study and debate, with several factors influencing the decision:
#
# *   **Resource Accessibility:** Proximity to vital resources like water ice (essential for life support, rocket fuel, and industry) and regolith (for construction and raw materials) is paramount. Craters at the poles, such as Shackleton Crater, are prime candidates due to their permanently shadowed regions where water ice is believed to exist.
# *   **Sunlight Availability:** While some areas are perpetually shadowed, others offer consistent sunlight, crucial for solar power generation. A balance between these two extremes is likely sought.
# *   **Geological Stability:** Stable terrain, free from significant seismic activity (though the Moon has very minor quakes), is preferred for construction.
# *   **Strategic Vantage Points:** Potential locations offering good views of Earth or crucial communication pathways might also be considered.
#
# **The Architecture and Infrastructure of Luna City:**
#
# Luna City's architecture would be dictated by the harsh lunar environment:
#
# *   **Subterranean and Shielded Structures:** The most critical infrastructure would likely be built underground or within protective berms of regolith to shield inhabitants from:
#     *   **Radiation:** The Moon lacks a significant atmosphere and magnetic field, leaving it exposed to harmful cosmic and solar radiation. Thick regolith offers excellent shielding.
#     *   **Micrometeoroids:** The constant bombardment of tiny space rocks poses a significant threat.
#     *   **Extreme Temperature Fluctuations:** Lunar days and nights experience drastic temperature swings. Underground living offers a more stable thermal environment.
# *   **Pressurized Domes and Habitats:** Above-ground structures would be sealed, pressurized habitats, likely constructed from advanced materials. These could range from modular units to larger, interconnected domes.
# *   **Regolith Utilization:** The Moon's abundant regolith would be a primary building material, processed and used for 3D printing structures, creating radiation shielding, and even potentially for growing plants in controlled environments.
# *   **Advanced Life Support Systems:** Self-sustaining and robust life support systems would be the backbone of Luna City, recycling air and water with extreme efficiency.
# *   **Power Generation:** A combination of solar power (leveraging extensive solar arrays) and potentially nuclear power would be crucial for the city's energy needs.
# *   **Transportation:**
#     *   **Pressurized Tunnels and Maglevs:** For travel between different sections of the city and to nearby mining or research facilities.
#     *   **Lunar Rovers:** For surface exploration and transport of materials.
#     *   **Low-Gravity Adapted Infrastructure:** Designs would account for the Moon's one-sixth gravity, influencing everything from building heights to personal mobility.
#
# **The Function of Luna City:**
#
# Luna City would serve a multitude of crucial roles:
#
# *   **Administrative Center:** The seat of governance for the lunar population, handling legal, economic, and diplomatic affairs related to the Moon.
# *   **Economic Hub:** A nexus for lunar industries, including:
#     *   **Resource Extraction:** Mining of water ice, helium-3 (for potential fusion power on Earth), rare earth elements, and other valuable minerals.
#     *   **Manufacturing and Production:** Using lunar resources to create goods for local use and potentially for export back to Earth.
#     *   **Scientific Research:** A central point for astronomical observatories, geological studies, and research into the long-term effects of living in a low-gravity, high-radiation environment.
#     *   **Tourism:** As lunar travel becomes more accessible, Luna City could become a prime destination for space tourists.
# *   **Social and Cultural Center:** A place for residents to live, work, socialize, and develop a unique lunar culture. This would include:
#     *   **Residential Areas:** Dwellings designed for comfort and habitability in the lunar environment.
#     *   **Recreation and Entertainment:** Facilities to promote well-being and combat the psychological challenges of isolation.
#     *   **Educational Institutions:** Schools and universities to train future generations of lunar inhabitants and scientists.
#     *   **Cultural Institutions:** Museums, art galleries, and performance spaces to foster lunar identity.
# *   **Logistics and Communications Hub:** A central point for receiving supplies from Earth, coordinating interplanetary missions, and managing lunar communication networks.
#
# **Life in Luna City:**
#
# Life in Luna City would be a unique experience, characterized by:
#
# *   **Low Gravity:** While an advantage for some activities, it would require adaptation in daily life, from walking and exercising to performing delicate tasks.
# *   **Artificial Environment:** Residents would spend most of their time in pressurized, controlled environments, with limited opportunities for "unfiltered" outdoor excursions.
# *   **Community and Interdependence:** Given the isolation and reliance on technology, a strong sense of community and mutual support would be essential.
# *   **Technological Reliance:** Advanced technology would be integrated into every aspect of life, from personal devices to public infrastructure.
# *   **The View:** The breathtaking and constant presence of Earth in the lunar sky would be a defining feature of life in Luna City.
#
# **Challenges and Future Considerations:**
#
# The realization of Luna City faces numerous hurdles:
#
# *   **Cost:** The immense financial investment required for its construction and ongoing operation is a significant barrier.
# *   **Technological Advancements:** Further innovation is needed in areas like radiation shielding, life support, and closed-loop systems.
# *   **Governance and Legal Frameworks:** Establishing a clear and equitable governance structure for a lunar settlement presents complex challenges.
# *   **Psychological Impact:** The long-term psychological effects of living in a closed, alien environment need careful consideration and mitigation strategies.
# *   **Sustainability:** Ensuring the long-term environmental sustainability of lunar activities and avoiding the mistakes made on Earth.
#
# **In Conclusion:**
#
# Luna City, the capital of the Moon, is more than just a collection of buildings. It represents humanity's ultimate ambition to become a multi-planetary species. It's a vision of innovation, resilience, and the enduring human drive to explore and settle new frontiers. While its full realization may be decades or even centuries away, the dream of Luna City continues to inspire and guide our journey beyond Earth.
